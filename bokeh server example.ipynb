# %%
import yaml

from bokeh.layouts import column
from bokeh.models import ColumnDataSource, Slider
from bokeh.plotting import figure
from bokeh.themes import Theme
from bokeh.io import show, output_notebook

from bokeh.sampledata.sea_surface_temperature import sea_surface_temperature

output_notebook()
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="6275">Loading BokehJS ...</span>
#     </div>

# %%
def modify_doc(doc):
    df = sea_surface_temperature.copy()
    source = ColumnDataSource(data=df)

    plot = figure(x_axis_type='datetime', y_range=(0, 25),
                  y_axis_label='Temperature (Celsius)',
                  title="Sea Surface Temperature at 43.18, -70.43")
    plot.line('time', 'temperature', source=source)

    def callback(attr, old, new):
        if new == 0:
            data = df
        else:
            data = df.rolling('{0}D'.format(new)).mean()
        source.data = ColumnDataSource(data=data).data

    slider = Slider(start=0, end=30, value=0, step=1, title="Smoothing by N Days")
    slider.on_change('value', callback)

    doc.add_root(column(slider, plot))

    doc.theme = Theme(json=yaml.load("""
        attrs:
            Figure:
                background_fill_color: "#DDDDDD"
                outline_line_color: white
                toolbar_location: above
                height: 500
                width: 800
            Grid:
                grid_line_dash: [6, 4]
                grid_line_color: white
    """))

# %%
show(modify_doc) # notebook_url="http://localhost:8888"
# Out:
# <script src="http://localhost:51240/autoload.js?bokeh-autoload-element=6276&bokeh-absolute-url=http://localhost:51240&resources=none" id="6276"></script>

# %%
# Out:
#                      temperature
# time
# 2016-02-15 00:00:00        4.929
# 2016-02-15 00:30:00        4.887
# 2016-02-15 01:00:00        4.821
# 2016-02-15 01:30:00        4.837
# 2016-02-15 02:00:00        4.830

# %%
df.head(10)
# Out:
#                      temperature
# time
# 2016-02-15 00:00:00        4.929
# 2016-02-15 00:30:00        4.887
# 2016-02-15 01:00:00        4.821
# 2016-02-15 01:30:00        4.837
# 2016-02-15 02:00:00        4.830
# 2016-02-15 02:30:00        4.777
# 2016-02-15 03:00:00        4.801
# 2016-02-15 03:30:00        4.821
# 2016-02-15 04:00:00        4.851
# 2016-02-15 04:30:00        4.831

# %%
df.shape
# Out:
# (19226, 1)

# %%
a=[[1,2],[3,4]]

# %%
a
# Out:
# [[1, 2], [3, 4]]

# %%
len(a)
# Out:
# 2

# %%
print(df.columns[0])
len(df.columns)
# Out:
# temperature
# 1

# %%
df.head(20)
# Out:
#                      temperature
# time
# 2016-02-15 00:00:00        4.929
# 2016-02-15 00:30:00        4.887
# 2016-02-15 01:00:00        4.821
# 2016-02-15 01:30:00        4.837
# 2016-02-15 02:00:00        4.830
# 2016-02-15 02:30:00        4.777
# 2016-02-15 03:00:00        4.801
# 2016-02-15 03:30:00        4.821
# 2016-02-15 04:00:00        4.851
# 2016-02-15 04:30:00        4.831
# 2016-02-15 05:00:00        4.885
# 2016-02-15 05:30:00        4.885
# 2016-02-15 06:00:00        4.946
# 2016-02-15 06:30:00        4.964
# 2016-02-15 07:00:00        4.826
# 2016-02-15 07:30:00        4.896
# 2016-02-15 08:00:00        4.790
# 2016-02-15 08:30:00        4.638
# 2016-02-15 09:00:00        4.671
# 2016-02-15 09:30:00        4.763

# %%
df.tail()
# Out:
#                      temperature
# time
# 2017-03-21 22:00:00        4.000
# 2017-03-21 22:30:00        3.975
# 2017-03-21 23:00:00        4.017
# 2017-03-21 23:30:00        4.121
# 2017-03-22 00:00:00        4.316

# %%
import yaml

from bokeh.layouts import column
from bokeh.models import ColumnDataSource, Slider
from bokeh.plotting import figure
from bokeh.themes import Theme
from bokeh.io import show, output_notebook

from bokeh.sampledata.iris import flowers

output_notebook()
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="2908">Loading BokehJS ...</span>
#     </div>

# %%
def modify_doc(doc):
    df = flowers.copy()

    source = ColumnDataSource(data=df)

    plot = figure(y_range=(0, 10),
                  y_axis_label='iris dataset',
                  title="Sea Surface Temperature at 43.18, -70.43")
    plot.line('sepal_length', 'petal_length', source=source)

    def callback(attr, old, new):
        if new == 0:
            data = df
        else:
            data = df.rolling('{0}D'.format(new)).mean()
        source.data = ColumnDataSource(data=data).data

    slider = Slider(start=0, end=30, value=0, step=1, title="Smoothing by N Days")
    slider.on_change('value', callback)
    
    y_axis = Select(title="Y Axis", options=list(df.columns), value=df.columns[0])
    y_axis.on_change('value', callback)
    
    doc.add_root(column(slider, plot))

    doc.theme = Theme(json=yaml.load("""
        attrs:
            Figure:
                background_fill_color: "#DDDDDD"
                outline_line_color: white
                toolbar_location: above
                height: 500
                width: 800
            Grid:
                grid_line_dash: [6, 4]
                grid_line_color: white
    """))
    

    y_axis = Select(title="Y Axis", options=headers, value=headers[1])

# %%
df = flowers.copy()
print(df.head())
print(df.columns)
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa
# Index(['sepal_length', 'sepal_width', 'petal_length', 'petal_width',
#        'species'],
#       dtype='object')

# %%
print(list(df.columns))
df.columns[0]
# Out:
# ['sepal_length', 'sepal_width', 'petal_length', 'petal_width', 'species']
# 'sepal_length'

# %%
df['x']=df.iloc[:,0]

# %%
df.head()
df['y']=df.iloc[:,1]

# %%
df.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species    x    y
# 0           5.1          3.5           1.4          0.2  setosa  5.1  3.5
# 1           4.9          3.0           1.4          0.2  setosa  4.9  3.0
# 2           4.7          3.2           1.3          0.2  setosa  4.7  3.2
# 3           4.6          3.1           1.5          0.2  setosa  4.6  3.1
# 4           5.0          3.6           1.4          0.2  setosa  5.0  3.6

# %%
import yaml

from bokeh.layouts import column
from bokeh.models import ColumnDataSource, Slider,Select
from bokeh.plotting import figure
from bokeh.themes import Theme
from bokeh.io import show, output_notebook

from bokeh.sampledata.iris import flowers

output_notebook()
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="2954">Loading BokehJS ...</span>
#     </div>

# %%
def modify_doc(doc):
    

    source = ColumnDataSource(data=df)

    plot = figure(y_range=(0, 10),
                  y_axis_label='iris dataset',
                  title="Sea Surface Temperature at 43.18, -70.43")
    plot.line('x', 'y', source=source)

    def callback(attr, old, new):
        if new == 0:
            data = df
        else:
            data = df.rolling('{0}D'.format(new)).mean()
        source.data = ColumnDataSource(data=data).data
        
    def callback1(attr, old, new):
        if new == 0:
            data = df
        else:
            data=df
            data['y'] = data[y_axis.value]
        source.data = ColumnDataSource(data=data).data

    slider = Slider(start=0, end=30, value=0, step=1, title="Smoothing by N Days")
    slider.on_change('value', callback)
    
    y_axis = Select(title="Y Axis", options=list(df.columns), value=df.columns[0])
    y_axis.on_change('value', callback1)
    
    doc.add_root(column(slider,y_axis, plot))

    doc.theme = Theme(json=yaml.load("""
        attrs:
            Figure:
                background_fill_color: "#DDDDDD"
                outline_line_color: white
                toolbar_location: above
                height: 500
                width: 800
            Grid:
                grid_line_dash: [6, 4]
                grid_line_color: white
    """))

# %%
show(modify_doc)
# Out:
# <script src="http://localhost:57134/autoload.js?bokeh-autoload-element=3358&bokeh-absolute-url=http://localhost:57134&resources=none" id="3358"></script>
# ERROR:bokeh.core.validation.check:E-1001 (BAD_COLUMN_NAME): Glyph refers to nonexistent column name: x [renderer: GlyphRenderer(id='3399', ...)]

# %%
df=flowers.copy()
df['x']=df.iloc[:,0]
df['y']=df.iloc[:,1]

# %%
df.head()
list((df.iloc[:,0:-2]).columns)
# Out:
# Index(['sepal_length', 'sepal_width', 'petal_length', 'petal_width',
#        'species'],
#       dtype='object')

# %%
def modify_doc(doc):
    

    source = ColumnDataSource(data=df)

    plot = figure(y_range=(0, 10),
                  y_axis_label='iris dataset',
                  title="Sea Surface Temperature at 43.18, -70.43")
    plot.line('x', 'y', source=source)

    def callback(attr, old, new):
        if new == 0:
            data = df
        else:
            data = df.rolling('{0}D'.format(new)).mean()
        source.data = ColumnDataSource(data=data).data
        
    def callback1(attr, old, new):
        if new == 0:
            data = df
        else:
            data=df
            data['y'] = data[y_axis.value]
        source.data = ColumnDataSource(data=data).data
    
    def callback2(attr, old, new):
        if new == 0:
            data = df
        else:
            data=df
            data['x'] = data[x_axis.value]
        source.data = ColumnDataSource(data=data).data

    
    slider = Slider(start=0, end=30, value=0, step=1, title="Smoothing by N Days")
    slider.on_change('value', callback)
    
    x_axis = Select(title="X Axis", options=list((df.iloc[:,0:-2]).columns), value=df.columns[0])
    x_axis.on_change('value', callback2)
    
    
    y_axis = Select(title="Y Axis", options=list((df.iloc[:,0:-2]).columns), value=df.columns[1])
    y_axis.on_change('value', callback1)
    
    doc.add_root(column(slider,x_axis,y_axis, plot))

    doc.theme = Theme(json=yaml.load("""
        attrs:
            Figure:
                background_fill_color: "#DDDDDD"
                outline_line_color: white
                toolbar_location: above
                height: 500
                width: 800
            Grid:
                grid_line_dash: [6, 4]
                grid_line_color: white
    """))

# %%
show(modify_doc)
# Out:
# <script src="http://localhost:57231/autoload.js?bokeh-autoload-element=3956&bokeh-absolute-url=http://localhost:57231&resources=none" id="3956"></script>
# ERROR:bokeh.server.protocol_handler:error handling message Message 'PATCH-DOC' (revision 1) content: {'events': [{'kind': 'ModelChanged', 'model': {'type': 'Slider', 'id': '3999'}, 'attr': 'value', 'new': 17}], 'references': []}: ValueError('window must be an integer')

# %%
df.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species    x    y
# 0           5.1          3.5           1.4          0.2  setosa  5.1  1.4
# 1           4.9          3.0           1.4          0.2  setosa  4.9  1.4
# 2           4.7          3.2           1.3          0.2  setosa  4.7  1.3
# 3           4.6          3.1           1.5          0.2  setosa  4.6  1.5
# 4           5.0          3.6           1.4          0.2  setosa  5.0  1.4
# ERROR:bokeh.server.protocol_handler:error handling message Message 'PATCH-DOC' (revision 1) content: {'events': [{'kind': 'ModelChanged', 'model': {'type': 'Slider', 'id': '3625'}, 'attr': 'value', 'new': 1}], 'references': []}: ValueError('window must be an integer')
# ERROR:bokeh.server.protocol_handler:error handling message Message 'PATCH-DOC' (revision 1) content: {'events': [{'kind': 'ModelChanged', 'model': {'type': 'Slider', 'id': '3625'}, 'attr': 'value', 'new': 2}], 'references': []}: ValueError('window must be an integer')
# ERROR:bokeh.server.protocol_handler:error handling message Message 'PATCH-DOC' (revision 1) content: {'events': [{'kind': 'ModelChanged', 'model': {'type': 'Slider', 'id': '3625'}, 'attr': 'value', 'new': 3}], 'references': []}: ValueError('window must be an integer')
# ERROR:bokeh.server.protocol_handler:error handling message Message 'PATCH-DOC' (revision 1) content: {'events': [{'kind': 'ModelChanged', 'model': {'type': 'Slider', 'id': '3625'}, 'attr': 'value', 'new': 4}], 'references': []}: ValueError('window must be an integer')
# ERROR:bokeh.server.protocol_handler:error handling message Message 'PATCH-DOC' (revision 1) content: {'events': [{'kind': 'ModelChanged', 'model': {'type': 'Slider', 'id': '3625'}, 'attr': 'value', 'new': 5}], 'references': []}: ValueError('window must be an integer')
# ERROR:bokeh.server.protocol_handler:error handling message Message 'PATCH-DOC' (revision 1) content: {'events': [{'kind': 'ModelChanged', 'model': {'type': 'Slider', 'id': '3625'}, 'attr': 'value', 'new': 6}], 'references': []}: ValueError('window must be an integer')
# ERROR:bokeh.server.protocol_handler:error handling message Message 'PATCH-DOC' (revision 1) content: {'events': [{'kind': 'ModelChanged', 'model': {'type': 'Slider', 'id': '3625'}, 'attr': 'value', 'new': 7}], 'references': []}: ValueError('window must be an integer')
# ERROR:bokeh.server.protocol_handler:error handling message Message 'PATCH-DOC' (revision 1) content: {'events': [{'kind': 'ModelChanged', 'model': {'type': 'Slider', 'id': '3625'}, 'attr': 'value', 'new': 8}], 'references': []}: ValueError('window must be an integer')
# ERROR:bokeh.server.protocol_handler:error handling message Message 'PATCH-DOC' (revision 1) content: {'events': [{'kind': 'ModelChanged', 'model': {'type': 'Slider', 'id': '3625'}, 'attr': 'value', 'new': 9}], 'references': []}: ValueError('window must be an integer')
# ERROR:bokeh.server.protocol_handler:error handling message Message 'PATCH-DOC' (revision 1) content: {'events': [{'kind': 'ModelChanged', 'model': {'type': 'Slider', 'id': '3625'}, 'attr': 'value', 'new': 10}], 'references': []}: ValueError('window must be an integer')
# ERROR:bokeh.server.protocol_handler:error handling message Message 'PATCH-DOC' (revision 1) content: {'events': [{'kind': 'ModelChanged', 'model': {'type': 'Slider', 'id': '3625'}, 'attr': 'value', 'new': 11}], 'references': []}: ValueError('window must be an integer')
# ERROR:bokeh.server.protocol_handler:error handling message Message 'PATCH-DOC' (revision 1) content: {'events': [{'kind': 'ModelChanged', 'model': {'type': 'Slider', 'id': '3625'}, 'attr': 'value', 'new': 12}], 'references': []}: ValueError('window must be an integer')
# ERROR:bokeh.server.protocol_handler:error handling message Message 'PATCH-DOC' (revision 1) content: {'events': [{'kind': 'ModelChanged', 'model': {'type': 'Slider', 'id': '3625'}, 'attr': 'value', 'new': 13}], 'references': []}: ValueError('window must be an integer')
# ERROR:bokeh.server.protocol_handler:error handling message Message 'PATCH-DOC' (revision 1) content: {'events': [{'kind': 'ModelChanged', 'model': {'type': 'Slider', 'id': '3625'}, 'attr': 'value', 'new': 14}], 'references': []}: ValueError('window must be an integer')
# ERROR:bokeh.server.protocol_handler:error handling message Message 'PATCH-DOC' (revision 1) content: {'events': [{'kind': 'ModelChanged', 'model': {'type': 'Slider', 'id': '3625'}, 'attr': 'value', 'new': 15}], 'references': []}: ValueError('window must be an integer')
# ERROR:bokeh.server.protocol_handler:error handling message Message 'PATCH-DOC' (revision 1) content: {'events': [{'kind': 'ModelChanged', 'model': {'type': 'Slider', 'id': '3625'}, 'attr': 'value', 'new': 16}], 'references': []}: ValueError('window must be an integer')
# ERROR:bokeh.server.protocol_handler:error handling message Message 'PATCH-DOC' (revision 1) content: {'events': [{'kind': 'ModelChanged', 'model': {'type': 'Slider', 'id': '3625'}, 'attr': 'value', 'new': 17}], 'references': []}: ValueError('window must be an integer')
# ERROR:bokeh.server.protocol_handler:error handling message Message 'PATCH-DOC' (revision 1) content: {'events': [{'kind': 'ModelChanged', 'model': {'type': 'Slider', 'id': '3625'}, 'attr': 'value', 'new': 18}], 'references': []}: ValueError('window must be an integer')
# ERROR:bokeh.server.protocol_handler:error handling message Message 'PATCH-DOC' (revision 1) content: {'events': [{'kind': 'ModelChanged', 'model': {'type': 'Slider', 'id': '3625'}, 'attr': 'value', 'new': 19}], 'references': []}: ValueError('window must be an integer')
# ERROR:bokeh.server.protocol_handler:error handling message Message 'PATCH-DOC' (revision 1) content: {'events': [{'kind': 'ModelChanged', 'model': {'type': 'Slider', 'id': '3625'}, 'attr': 'value', 'new': 20}], 'references': []}: ValueError('window must be an integer')
# ERROR:bokeh.server.protocol_handler:error handling message Message 'PATCH-DOC' (revision 1) content: {'events': [{'kind': 'ModelChanged', 'model': {'type': 'Slider', 'id': '3625'}, 'attr': 'value', 'new': 21}], 'references': []}: ValueError('window must be an integer')
# ERROR:bokeh.server.protocol_handler:error handling message Message 'PATCH-DOC' (revision 1) content: {'events': [{'kind': 'ModelChanged', 'model': {'type': 'Slider', 'id': '3625'}, 'attr': 'value', 'new': 22}], 'references': []}: ValueError('window must be an integer')
# ERROR:bokeh.server.protocol_handler:error handling message Message 'PATCH-DOC' (revision 1) content: {'events': [{'kind': 'ModelChanged', 'model': {'type': 'Slider', 'id': '3625'}, 'attr': 'value', 'new': 23}], 'references': []}: ValueError('window must be an integer')
# ERROR:bokeh.server.protocol_handler:error handling message Message 'PATCH-DOC' (revision 1) content: {'events': [{'kind': 'ModelChanged', 'model': {'type': 'Slider', 'id': '3625'}, 'attr': 'value', 'new': 24}], 'references': []}: ValueError('window must be an integer')
# ERROR:bokeh.server.protocol_handler:error handling message Message 'PATCH-DOC' (revision 1) content: {'events': [{'kind': 'ModelChanged', 'model': {'type': 'Slider', 'id': '3625'}, 'attr': 'value', 'new': 25}], 'references': []}: ValueError('window must be an integer')
# ERROR:bokeh.server.protocol_handler:error handling message Message 'PATCH-DOC' (revision 1) content: {'events': [{'kind': 'ModelChanged', 'model': {'type': 'Slider', 'id': '3625'}, 'attr': 'value', 'new': 26}], 'references': []}: ValueError('window must be an integer')
# ERROR:bokeh.server.protocol_handler:error handling message Message 'PATCH-DOC' (revision 1) content: {'events': [{'kind': 'ModelChanged', 'model': {'type': 'Slider', 'id': '3625'}, 'attr': 'value', 'new': 27}], 'references': []}: ValueError('window must be an integer')
# ERROR:bokeh.server.protocol_handler:error handling message Message 'PATCH-DOC' (revision 1) content: {'events': [{'kind': 'ModelChanged', 'model': {'type': 'Slider', 'id': '3625'}, 'attr': 'value', 'new': 28}], 'references': []}: ValueError('window must be an integer')
# ERROR:bokeh.server.protocol_handler:error handling message Message 'PATCH-DOC' (revision 1) content: {'events': [{'kind': 'ModelChanged', 'model': {'type': 'Slider', 'id': '3625'}, 'attr': 'value', 'new': 29}], 'references': []}: ValueError('window must be an integer')
# ERROR:bokeh.server.protocol_handler:error handling message Message 'PATCH-DOC' (revision 1) content: {'events': [{'kind': 'ModelChanged', 'model': {'type': 'Slider', 'id': '3625'}, 'attr': 'value', 'new': 30}], 'references': []}: ValueError('window must be an integer')
# ERROR:bokeh.server.protocol_handler:error handling message Message 'PATCH-DOC' (revision 1) content: {'events': [{'kind': 'ModelChanged', 'model': {'type': 'Slider', 'id': '3625'}, 'attr': 'value', 'new': 29}], 'references': []}: ValueError('window must be an integer')
# ERROR:bokeh.server.protocol_handler:error handling message Message 'PATCH-DOC' (revision 1) content: {'events': [{'kind': 'ModelChanged', 'model': {'type': 'Slider', 'id': '3625'}, 'attr': 'value', 'new': 28}], 'references': []}: ValueError('window must be an integer')
# ERROR:bokeh.server.protocol_handler:error handling message Message 'PATCH-DOC' (revision 1) content: {'events': [{'kind': 'ModelChanged', 'model': {'type': 'Slider', 'id': '3625'}, 'attr': 'value', 'new': 27}], 'references': []}: ValueError('window must be an integer')
# ERROR:bokeh.server.protocol_handler:error handling message Message 'PATCH-DOC' (revision 1) content: {'events': [{'kind': 'ModelChanged', 'model': {'type': 'Slider', 'id': '3625'}, 'attr': 'value', 'new': 26}], 'references': []}: ValueError('window must be an integer')
# ERROR:bokeh.server.protocol_handler:error handling message Message 'PATCH-DOC' (revision 1) content: {'events': [{'kind': 'ModelChanged', 'model': {'type': 'Slider', 'id': '3625'}, 'attr': 'value', 'new': 25}], 'references': []}: ValueError('window must be an integer')
# ERROR:bokeh.server.protocol_handler:error handling message Message 'PATCH-DOC' (revision 1) content: {'events': [{'kind': 'ModelChanged', 'model': {'type': 'Slider', 'id': '3625'}, 'attr': 'value', 'new': 24}], 'references': []}: ValueError('window must be an integer')
# ERROR:bokeh.server.protocol_handler:error handling message Message 'PATCH-DOC' (revision 1) content: {'events': [{'kind': 'ModelChanged', 'model': {'type': 'Slider', 'id': '3625'}, 'attr': 'value', 'new': 23}], 'references': []}: ValueError('window must be an integer')
# ERROR:bokeh.server.protocol_handler:error handling message Message 'PATCH-DOC' (revision 1) content: {'events': [{'kind': 'ModelChanged', 'model': {'type': 'Slider', 'id': '3625'}, 'attr': 'value', 'new': 22}], 'references': []}: ValueError('window must be an integer')
# ERROR:bokeh.server.protocol_handler:error handling message Message 'PATCH-DOC' (revision 1) content: {'events': [{'kind': 'ModelChanged', 'model': {'type': 'Slider', 'id': '3625'}, 'attr': 'value', 'new': 21}], 'references': []}: ValueError('window must be an integer')
# ERROR:bokeh.server.protocol_handler:error handling message Message 'PATCH-DOC' (revision 1) content: {'events': [{'kind': 'ModelChanged', 'model': {'type': 'Slider', 'id': '3625'}, 'attr': 'value', 'new': 20}], 'references': []}: ValueError('window must be an integer')
# ERROR:bokeh.server.protocol_handler:error handling message Message 'PATCH-DOC' (revision 1) content: {'events': [{'kind': 'ModelChanged', 'model': {'type': 'Slider', 'id': '3625'}, 'attr': 'value', 'new': 19}], 'references': []}: ValueError('window must be an integer')
# ERROR:bokeh.server.protocol_handler:error handling message Message 'PATCH-DOC' (revision 1) content: {'events': [{'kind': 'ModelChanged', 'model': {'type': 'Slider', 'id': '3625'}, 'attr': 'value', 'new': 18}], 'references': []}: ValueError('window must be an integer')
# ERROR:bokeh.server.protocol_handler:error handling message Message 'PATCH-DOC' (revision 1) content: {'events': [{'kind': 'ModelChanged', 'model': {'type': 'Slider', 'id': '3625'}, 'attr': 'value', 'new': 17}], 'references': []}: ValueError('window must be an integer')
# ERROR:bokeh.server.protocol_handler:error handling message Message 'PATCH-DOC' (revision 1) content: {'events': [{'kind': 'ModelChanged', 'model': {'type': 'Slider', 'id': '3625'}, 'attr': 'value', 'new': 16}], 'references': []}: ValueError('window must be an integer')
# ERROR:bokeh.server.protocol_handler:error handling message Message 'PATCH-DOC' (revision 1) content: {'events': [{'kind': 'ModelChanged', 'model': {'type': 'Slider', 'id': '3625'}, 'attr': 'value', 'new': 15}], 'references': []}: ValueError('window must be an integer')
# ERROR:bokeh.server.protocol_handler:error handling message Message 'PATCH-DOC' (revision 1) content: {'events': [{'kind': 'ModelChanged', 'model': {'type': 'Slider', 'id': '3625'}, 'attr': 'value', 'new': 14}], 'references': []}: ValueError('window must be an integer')
# ERROR:bokeh.server.protocol_handler:error handling message Message 'PATCH-DOC' (revision 1) content: {'events': [{'kind': 'ModelChanged', 'model': {'type': 'Slider', 'id': '3625'}, 'attr': 'value', 'new': 13}], 'references': []}: ValueError('window must be an integer')
# ERROR:bokeh.server.protocol_handler:error handling message Message 'PATCH-DOC' (revision 1) content: {'events': [{'kind': 'ModelChanged', 'model': {'type': 'Slider', 'id': '3625'}, 'attr': 'value', 'new': 12}], 'references': []}: ValueError('window must be an integer')
# ERROR:bokeh.server.protocol_handler:error handling message Message 'PATCH-DOC' (revision 1) content: {'events': [{'kind': 'ModelChanged', 'model': {'type': 'Slider', 'id': '3625'}, 'attr': 'value', 'new': 11}], 'references': []}: ValueError('window must be an integer')
# ERROR:bokeh.server.protocol_handler:error handling message Message 'PATCH-DOC' (revision 1) content: {'events': [{'kind': 'ModelChanged', 'model': {'type': 'Slider', 'id': '3625'}, 'attr': 'value', 'new': 10}], 'references': []}: ValueError('window must be an integer')
# ERROR:bokeh.server.protocol_handler:error handling message Message 'PATCH-DOC' (revision 1) content: {'events': [{'kind': 'ModelChanged', 'model': {'type': 'Slider', 'id': '3625'}, 'attr': 'value', 'new': 9}], 'references': []}: ValueError('window must be an integer')
# ERROR:bokeh.server.protocol_handler:error handling message Message 'PATCH-DOC' (revision 1) content: {'events': [{'kind': 'ModelChanged', 'model': {'type': 'Slider', 'id': '3625'}, 'attr': 'value', 'new': 8}], 'references': []}: ValueError('window must be an integer')
# ERROR:bokeh.server.protocol_handler:error handling message Message 'PATCH-DOC' (revision 1) content: {'events': [{'kind': 'ModelChanged', 'model': {'type': 'Slider', 'id': '3625'}, 'attr': 'value', 'new': 7}], 'references': []}: ValueError('window must be an integer')
# ERROR:bokeh.server.protocol_handler:error handling message Message 'PATCH-DOC' (revision 1) content: {'events': [{'kind': 'ModelChanged', 'model': {'type': 'Slider', 'id': '3625'}, 'attr': 'value', 'new': 6}], 'references': []}: ValueError('window must be an integer')
# ERROR:bokeh.server.protocol_handler:error handling message Message 'PATCH-DOC' (revision 1) content: {'events': [{'kind': 'ModelChanged', 'model': {'type': 'Slider', 'id': '3625'}, 'attr': 'value', 'new': 5}], 'references': []}: ValueError('window must be an integer')
# ERROR:bokeh.server.protocol_handler:error handling message Message 'PATCH-DOC' (revision 1) content: {'events': [{'kind': 'ModelChanged', 'model': {'type': 'Slider', 'id': '3625'}, 'attr': 'value', 'new': 4}], 'references': []}: ValueError('window must be an integer')
# ERROR:bokeh.server.protocol_handler:error handling message Message 'PATCH-DOC' (revision 1) content: {'events': [{'kind': 'ModelChanged', 'model': {'type': 'Slider', 'id': '3625'}, 'attr': 'value', 'new': 3}], 'references': []}: ValueError('window must be an integer')
# ERROR:bokeh.server.protocol_handler:error handling message Message 'PATCH-DOC' (revision 1) content: {'events': [{'kind': 'ModelChanged', 'model': {'type': 'Slider', 'id': '3625'}, 'attr': 'value', 'new': 2}], 'references': []}: ValueError('window must be an integer')
# ERROR:bokeh.server.protocol_handler:error handling message Message 'PATCH-DOC' (revision 1) content: {'events': [{'kind': 'ModelChanged', 'model': {'type': 'Slider', 'id': '3625'}, 'attr': 'value', 'new': 1}], 'references': []}: ValueError('window must be an integer')
# ERROR:bokeh.server.protocol_handler:error handling message Message 'PATCH-DOC' (revision 1) content: {'events': [{'kind': 'ModelChanged', 'model': {'type': 'Slider', 'id': '3625'}, 'attr': 'value', 'new': 1}], 'references': []}: ValueError('window must be an integer')
# ERROR:bokeh.server.protocol_handler:error handling message Message 'PATCH-DOC' (revision 1) content: {'events': [{'kind': 'ModelChanged', 'model': {'type': 'Slider', 'id': '3625'}, 'attr': 'value', 'new': 2}], 'references': []}: ValueError('window must be an integer')
# ERROR:bokeh.server.protocol_handler:error handling message Message 'PATCH-DOC' (revision 1) content: {'events': [{'kind': 'ModelChanged', 'model': {'type': 'Slider', 'id': '3625'}, 'attr': 'value', 'new': 3}], 'references': []}: ValueError('window must be an integer')
# ERROR:bokeh.server.protocol_handler:error handling message Message 'PATCH-DOC' (revision 1) content: {'events': [{'kind': 'ModelChanged', 'model': {'type': 'Slider', 'id': '3625'}, 'attr': 'value', 'new': 4}], 'references': []}: ValueError('window must be an integer')
# ERROR:bokeh.server.protocol_handler:error handling message Message 'PATCH-DOC' (revision 1) content: {'events': [{'kind': 'ModelChanged', 'model': {'type': 'Slider', 'id': '3625'}, 'attr': 'value', 'new': 8}], 'references': []}: ValueError('window must be an integer')
# ERROR:bokeh.server.protocol_handler:error handling message Message 'PATCH-DOC' (revision 1) content: {'events': [{'kind': 'ModelChanged', 'model': {'type': 'Slider', 'id': '3625'}, 'attr': 'value', 'new': 9}], 'references': []}: ValueError('window must be an integer')
# ERROR:bokeh.server.protocol_handler:error handling message Message 'PATCH-DOC' (revision 1) content: {'events': [{'kind': 'ModelChanged', 'model': {'type': 'Slider', 'id': '3625'}, 'attr': 'value', 'new': 12}], 'references': []}: ValueError('window must be an integer')
# ERROR:bokeh.server.protocol_handler:error handling message Message 'PATCH-DOC' (revision 1) content: {'events': [{'kind': 'ModelChanged', 'model': {'type': 'Slider', 'id': '3625'}, 'attr': 'value', 'new': 14}], 'references': []}: ValueError('window must be an integer')
# ERROR:bokeh.server.protocol_handler:error handling message Message 'PATCH-DOC' (revision 1) content: {'events': [{'kind': 'ModelChanged', 'model': {'type': 'Slider', 'id': '3625'}, 'attr': 'value', 'new': 15}], 'references': []}: ValueError('window must be an integer')
# ERROR:bokeh.server.protocol_handler:error handling message Message 'PATCH-DOC' (revision 1) content: {'events': [{'kind': 'ModelChanged', 'model': {'type': 'Slider', 'id': '3625'}, 'attr': 'value', 'new': 17}], 'references': []}: ValueError('window must be an integer')
# ERROR:bokeh.server.protocol_handler:error handling message Message 'PATCH-DOC' (revision 1) content: {'events': [{'kind': 'ModelChanged', 'model': {'type': 'Slider', 'id': '3625'}, 'attr': 'value', 'new': 19}], 'references': []}: ValueError('window must be an integer')
# ERROR:bokeh.server.protocol_handler:error handling message Message 'PATCH-DOC' (revision 1) content: {'events': [{'kind': 'ModelChanged', 'model': {'type': 'Slider', 'id': '3625'}, 'attr': 'value', 'new': 21}], 'references': []}: ValueError('window must be an integer')
# ERROR:bokeh.server.protocol_handler:error handling message Message 'PATCH-DOC' (revision 1) content: {'events': [{'kind': 'ModelChanged', 'model': {'type': 'Slider', 'id': '3625'}, 'attr': 'value', 'new': 22}], 'references': []}: ValueError('window must be an integer')
# ERROR:bokeh.server.protocol_handler:error handling message Message 'PATCH-DOC' (revision 1) content: {'events': [{'kind': 'ModelChanged', 'model': {'type': 'Slider', 'id': '3625'}, 'attr': 'value', 'new': 24}], 'references': []}: ValueError('window must be an integer')
# ERROR:bokeh.server.protocol_handler:error handling message Message 'PATCH-DOC' (revision 1) content: {'events': [{'kind': 'ModelChanged', 'model': {'type': 'Slider', 'id': '3625'}, 'attr': 'value', 'new': 25}], 'references': []}: ValueError('window must be an integer')
# ERROR:bokeh.server.protocol_handler:error handling message Message 'PATCH-DOC' (revision 1) content: {'events': [{'kind': 'ModelChanged', 'model': {'type': 'Slider', 'id': '3625'}, 'attr': 'value', 'new': 27}], 'references': []}: ValueError('window must be an integer')
# ERROR:bokeh.server.protocol_handler:error handling message Message 'PATCH-DOC' (revision 1) content: {'events': [{'kind': 'ModelChanged', 'model': {'type': 'Slider', 'id': '3625'}, 'attr': 'value', 'new': 28}], 'references': []}: ValueError('window must be an integer')
# ERROR:bokeh.server.protocol_handler:error handling message Message 'PATCH-DOC' (revision 1) content: {'events': [{'kind': 'ModelChanged', 'model': {'type': 'Slider', 'id': '3625'}, 'attr': 'value', 'new': 29}], 'references': []}: ValueError('window must be an integer')
# ERROR:bokeh.server.protocol_handler:error handling message Message 'PATCH-DOC' (revision 1) content: {'events': [{'kind': 'ModelChanged', 'model': {'type': 'Slider', 'id': '3625'}, 'attr': 'value', 'new': 30}], 'references': []}: ValueError('window must be an integer')
# ERROR:bokeh.server.protocol_handler:error handling message Message 'PATCH-DOC' (revision 1) content: {'events': [{'kind': 'ModelChanged', 'model': {'type': 'Slider', 'id': '3625'}, 'attr': 'value', 'new': 29}], 'references': []}: ValueError('window must be an integer')
# ERROR:bokeh.server.protocol_handler:error handling message Message 'PATCH-DOC' (revision 1) content: {'events': [{'kind': 'ModelChanged', 'model': {'type': 'Slider', 'id': '3625'}, 'attr': 'value', 'new': 28}], 'references': []}: ValueError('window must be an integer')
# ERROR:bokeh.server.protocol_handler:error handling message Message 'PATCH-DOC' (revision 1) content: {'events': [{'kind': 'ModelChanged', 'model': {'type': 'Slider', 'id': '3625'}, 'attr': 'value', 'new': 26}], 'references': []}: ValueError('window must be an integer')
# ERROR:bokeh.server.protocol_handler:error handling message Message 'PATCH-DOC' (revision 1) content: {'events': [{'kind': 'ModelChanged', 'model': {'type': 'Slider', 'id': '3625'}, 'attr': 'value', 'new': 23}], 'references': []}: ValueError('window must be an integer')
# ERROR:bokeh.server.protocol_handler:error handling message Message 'PATCH-DOC' (revision 1) content: {'events': [{'kind': 'ModelChanged', 'model': {'type': 'Slider', 'id': '3625'}, 'attr': 'value', 'new': 19}], 'references': []}: ValueError('window must be an integer')
# ERROR:bokeh.server.protocol_handler:error handling message Message 'PATCH-DOC' (revision 1) content: {'events': [{'kind': 'ModelChanged', 'model': {'type': 'Slider', 'id': '3625'}, 'attr': 'value', 'new': 18}], 'references': []}: ValueError('window must be an integer')
# ERROR:bokeh.server.protocol_handler:error handling message Message 'PATCH-DOC' (revision 1) content: {'events': [{'kind': 'ModelChanged', 'model': {'type': 'Slider', 'id': '3625'}, 'attr': 'value', 'new': 16}], 'references': []}: ValueError('window must be an integer')
# ERROR:bokeh.server.protocol_handler:error handling message Message 'PATCH-DOC' (revision 1) content: {'events': [{'kind': 'ModelChanged', 'model': {'type': 'Slider', 'id': '3625'}, 'attr': 'value', 'new': 15}], 'references': []}: ValueError('window must be an integer')
# ERROR:bokeh.server.protocol_handler:error handling message Message 'PATCH-DOC' (revision 1) content: {'events': [{'kind': 'ModelChanged', 'model': {'type': 'Slider', 'id': '3625'}, 'attr': 'value', 'new': 14}], 'references': []}: ValueError('window must be an integer')
# ERROR:bokeh.server.protocol_handler:error handling message Message 'PATCH-DOC' (revision 1) content: {'events': [{'kind': 'ModelChanged', 'model': {'type': 'Slider', 'id': '3625'}, 'attr': 'value', 'new': 13}], 'references': []}: ValueError('window must be an integer')
# ERROR:bokeh.server.protocol_handler:error handling message Message 'PATCH-DOC' (revision 1) content: {'events': [{'kind': 'ModelChanged', 'model': {'type': 'Slider', 'id': '3625'}, 'attr': 'value', 'new': 12}], 'references': []}: ValueError('window must be an integer')
# ERROR:bokeh.server.protocol_handler:error handling message Message 'PATCH-DOC' (revision 1) content: {'events': [{'kind': 'ModelChanged', 'model': {'type': 'Slider', 'id': '3625'}, 'attr': 'value', 'new': 11}], 'references': []}: ValueError('window must be an integer')
# ERROR:bokeh.server.protocol_handler:error handling message Message 'PATCH-DOC' (revision 1) content: {'events': [{'kind': 'ModelChanged', 'model': {'type': 'Slider', 'id': '3625'}, 'attr': 'value', 'new': 10}], 'references': []}: ValueError('window must be an integer')
# ERROR:bokeh.server.protocol_handler:error handling message Message 'PATCH-DOC' (revision 1) content: {'events': [{'kind': 'ModelChanged', 'model': {'type': 'Slider', 'id': '3625'}, 'attr': 'value', 'new': 9}], 'references': []}: ValueError('window must be an integer')
# ERROR:bokeh.server.protocol_handler:error handling message Message 'PATCH-DOC' (revision 1) content: {'events': [{'kind': 'ModelChanged', 'model': {'type': 'Slider', 'id': '3625'}, 'attr': 'value', 'new': 8}], 'references': []}: ValueError('window must be an integer')
# ERROR:bokeh.server.protocol_handler:error handling message Message 'PATCH-DOC' (revision 1) content: {'events': [{'kind': 'ModelChanged', 'model': {'type': 'Slider', 'id': '3625'}, 'attr': 'value', 'new': 7}], 'references': []}: ValueError('window must be an integer')
# ERROR:bokeh.server.protocol_handler:error handling message Message 'PATCH-DOC' (revision 1) content: {'events': [{'kind': 'ModelChanged', 'model': {'type': 'Slider', 'id': '3625'}, 'attr': 'value', 'new': 6}], 'references': []}: ValueError('window must be an integer')
# ERROR:bokeh.server.protocol_handler:error handling message Message 'PATCH-DOC' (revision 1) content: {'events': [{'kind': 'ModelChanged', 'model': {'type': 'Slider', 'id': '3625'}, 'attr': 'value', 'new': 5}], 'references': []}: ValueError('window must be an integer')
# ERROR:bokeh.server.protocol_handler:error handling message Message 'PATCH-DOC' (revision 1) content: {'events': [{'kind': 'ModelChanged', 'model': {'type': 'Slider', 'id': '3625'}, 'attr': 'value', 'new': 4}], 'references': []}: ValueError('window must be an integer')
# ERROR:bokeh.server.protocol_handler:error handling message Message 'PATCH-DOC' (revision 1) content: {'events': [{'kind': 'ModelChanged', 'model': {'type': 'Slider', 'id': '3625'}, 'attr': 'value', 'new': 3}], 'references': []}: ValueError('window must be an integer')
# ERROR:bokeh.server.protocol_handler:error handling message Message 'PATCH-DOC' (revision 1) content: {'events': [{'kind': 'ModelChanged', 'model': {'type': 'Slider', 'id': '3625'}, 'attr': 'value', 'new': 2}], 'references': []}: ValueError('window must be an integer')
# ERROR:bokeh.server.protocol_handler:error handling message Message 'PATCH-DOC' (revision 1) content: {'events': [{'kind': 'ModelChanged', 'model': {'type': 'Slider', 'id': '3625'}, 'attr': 'value', 'new': 1}], 'references': []}: ValueError('window must be an integer')
# ERROR:bokeh.server.protocol_handler:error handling message Message 'PATCH-DOC' (revision 1) content: {'events': [{'kind': 'ModelChanged', 'model': {'type': 'Slider', 'id': '3625'}, 'attr': 'value', 'new': 5}], 'references': []}: ValueError('window must be an integer')
# ERROR:bokeh.server.protocol_handler:error handling message Message 'PATCH-DOC' (revision 1) content: {'events': [{'kind': 'ModelChanged', 'model': {'type': 'Slider', 'id': '3625'}, 'attr': 'value', 'new': 12}], 'references': []}: ValueError('window must be an integer')
# ERROR:bokeh.server.protocol_handler:error handling message Message 'PATCH-DOC' (revision 1) content: {'events': [{'kind': 'ModelChanged', 'model': {'type': 'Slider', 'id': '3625'}, 'attr': 'value', 'new': 21}], 'references': []}: ValueError('window must be an integer')
